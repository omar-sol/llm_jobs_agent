# %%
import json
def flatten_dict(d, parent_key='', sep='_', parent_keys=set()):
    items = []
    for k, v in d.items():
        # Check if key is unique in the context of parent keys
        new_key = k if (k not in parent_keys) else f'{parent_key}{sep}{k}' if parent_key else k
        if isinstance(v, dict):
            # Update the set of parent keys for the next level
            new_parent_keys = parent_keys.union(set(d.keys()))
            items.extend(flatten_dict(v, new_key, sep, new_parent_keys).items())
        else:
            items.append((new_key, v))
    return dict(items)

def read_jsonl_and_flatten(file_path):
    flattened_data = []
    with open(file_path, 'r') as file:
        for line in file:
            # Load the line as a JSON object
            data_dict = json.loads(line)
            # Flatten the dictionary
            flattened_dict = flatten_dict(data_dict)
            
            # Might be better to clean this in another function
            # Check if the dictionary has the right number of keys
            if len(flattened_dict.keys()) != 34:
                print("Skipping due to wrong number of keys")
                print(flattened_dict.keys())
                print(flattened_dict)
                continue 

            if flattened_dict["jobs_towardsai_url"] == 'nan':
                print("Skipping due to nan url")
                print(flattened_dict)
                continue
            
            # Add the flattened dictionary to the list
            flattened_data.append(flattened_dict)

    return flattened_data

# Example usage
file_path = '../data/formatted_jobs_feb5_24_results.jsonl'
flattened_data = read_jsonl_and_flatten(file_path)
print("end of file")
print(flattened_data[0])
print(len(flattened_data[0].keys()))
print(flattened_data[9].keys())
# Out:
# Skipping due to wrong number of keys
# dict_keys(['job_id', 'created_at', 'title', 'skills', 'company_id', 'apply_url', 'city', 'country', 'slug', 'ai', 'approved', 'company_name', 'cleaned_description', 'jobs_towardsai_url', 'extracted_info'])
# {'job_id': 67964, 'created_at': '2024-02-03', 'title': 'Machine Learning and Data Engineer', 'skills': 'Machine Learning,Data Engineer', 'company_id': 83543, 'apply_url': 'https://jobs.smartrecruiters.com/SoltiaAB/743999965032933-machine-learning-and-data-engineer?utm_source=found.dev', 'city': 'Alvsjo', 'country': 'Sweden', 'slug': 'soltia-ab-machine-learning-and-data-engineer-enbx', 'ai': 1, 'approved': 1, 'company_name': 'Soltia AB', 'cleaned_description': 'SmartRecruiters - Down For Maintenance\\# Down For MaintenanceSmartRecruiters is currently not available as we are performing scheduled maintenanceWe apologize for any inconvenience to you and your businessFor additional information please follow our \\[Status Page\\](http://statussmartrecruiterscom/) for real-time updates\\[Maitenance Page Bulb\\](data:image/png;...)', 'jobs_towardsai_url': 'https://jobs.towardsai.net/job/soltia-ab-machine-learning-and-data-engineer-enbx', 'extracted_info': ["Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo-0125 in organization org-U6kaY41TWyFfnlzuqEfQ6i5h on tokens per min (TPM): Limit 160000, Used 158928, Requested 7576. Please try again in 2.439s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}", "Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo-0125 in organization org-U6kaY41TWyFfnlzuqEfQ6i5h on tokens per min (TPM): Limit 160000, Used 153775, Requested 7576. Please try again in 506ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}", "Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo-0125 in organization org-U6kaY41TWyFfnlzuqEfQ6i5h on tokens per min (TPM): Limit 160000, Used 157032, Requested 7576. Please try again in 1.728s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}", 'Error code: 400 - {\'error\': {\'message\': "This model\'s maximum context length is 16385 tokens. However, your messages resulted in 22380 tokens (20977 in the messages, 1403 in the functions). Please reduce the length of the messages or functions.", \'type\': \'invalid_request_error\', \'param\': \'messages\', \'code\': \'context_length_exceeded\'}}', 'Error code: 400 - {\'error\': {\'message\': "This model\'s maximum context length is 16385 tokens. However, your messages resulted in 22380 tokens (20977 in the messages, 1403 in the functions). Please reduce the length of the messages or functions.", \'type\': \'invalid_request_error\', \'param\': \'messages\', \'code\': \'context_length_exceeded\'}}']}
# end of file
# {'job_id': 57, 'created_at': '2023-10-22', 'title': 'ML Research Intern', 'skills': 'IOS,Deep Learning,ML Research,Neural networks,Machine Learning,Architecture,2D,3D,Graph,Testing,PyTorch,DataSets,Physics,Chemistry,Biochemistry,AI,Intern,Gaming,Google Analytics', 'company_id': 6977, 'apply_url': 'https://jobs.lever.co/genesistherapeutics/2c7e03e2-3789-4c0f-98d9-d1f835963897?utm_source=found.dev', 'city': 'Burlingame, CA', 'country': 'USA', 'slug': 'genesis-therapeutics-ml-research-intern-jf8v', 'ai': 1, 'approved': 1, 'company_name': 'Genesis Therapeutics', 'cleaned_description': '<p>Genesis is building a world-class ML team in an industry that has  underutilized computational methods for too long. We are creating the  best molecular generation and property prediction platform in the world  filling in a critical piece in the drug discovery process. We need you  to drive the cutting-edge research that will enable us to find cures for  a wider range of diseases faster than ever before.</p>\\n<p><p><br></p><b>You will</b><ul><li>Drive speed and accuracy improvements in our ML platform coming up with architecture modifications for 2D and 3D graph neural networks and rapidly implementing and testing them in pytorch</li><li>Keep up with deep learning research especially pertaining to graph neural nets and graph generative models and quickly prototype ideas gleaned from the literature</li><li>Dive deep into molecular datasets creating statistically rigorous train valid and test sets to optimally train our models for real-world prediction and generation tasks</li><li>Develop creative featurizations of 2D and 3D molecular structures that are inspired by laws of physics and chemistry enabling our networks to take better advantage of available data</li><li>Work closely with software engineers and medicinal chemists to make our ML platform maximally adaptive to different use cases</li></ul><p><br></p><b>You are</b><ul><li>A strong software engineer who will write code quickly and uphold our code quality standards</li><li>A deep thinker who reasons from first principles over pattern matching</li><li>Interested in learning about biochemistry and the drug development process</li></ul><p><br></p><b>What we offer</b><ul><li>The opportunity to work on challenging high impact ML research that is immediately deployed to accelerate the discovery of new medicines</li><li>One-on-one mentorship to help guide your research and act as a point person for questions</li><li>Strong technical coworkers in AI software and chemistry who all have a powerful mix of intellectual curiosity and humility. The team reads and discusses 1-2 ML or chemistry papers every week to stay on top of the field and inspire new ideas</li></ul><p><br></p></p>\\n<p><b style="font-size: 15px">Finding the best talent is our top priority at Genesis Therapeutics. If you are interested in potential partnership on recruitment please reach out to&nbsp;</b><a href="mailto:recruiting@genesistherapeutics.ai" style="font-size: 15px" class="postings-link"><b>recruiting@genesistherapeutics.ai</b></a><b style="font-size: 15px">.</b></p>   ', 'jobs_towardsai_url': 'https://jobs.towardsai.net/job/genesis-therapeutics-ml-research-intern-jf8v', 'company_info': 'Genesis is building a world-class ML team in an industry that has underutilized computational methods for too long. They are creating the best molecular generation and property prediction platform in the world, filling in a critical piece in the drug discovery process.', 'role_description': 'Drive speed and accuracy improvements in the ML platform, focusing on architecture modifications for 2D and 3D graph neural networks in PyTorch. Keep up with deep learning research, prototype ideas from literature, create datasets for training ML models, develop featurizations of molecular structures, and collaborate with software engineers and chemists. Seeking a strong software engineer interested in biochemistry and drug development.', 'chain_of_thou ...
# 34
# dict_keys(['job_id', 'created_at', 'title', 'skills', 'company_id', 'apply_url', 'city', 'country', 'slug', 'ai', 'approved', 'company_name', 'cleaned_description', 'jobs_towardsai_url', 'company_info', 'role_description', 'chain_of_thought', 'required_skills', 'preferred_skills', 'salary_reasoning', 'salary_numerical', 'salary_frequency', 'salary_currency', 'job_type_reasoning', 'job_type_answer', 'min_experience_years', 'location_model_city', 'regions_or_states', 'location_model_country', 'continent', 'experience_level', 'involves_ai', 'remote_reasoning', 'remote_answer'])

# %%
import math

def optimize_keys(data_dict):
    # Function to check if a value is valid (not None, Nan, empty string, or 'Not Specified')

    def is_valid(value):
        # Check for None
        if value is None:
            return False

        # Check for NaN for float values
        if isinstance(value, float) and math.isnan(value):
            return False

        # Check for empty strings and lists
        if value == "" or value == []:
            return False

        # Case-insensitive check for specific strings
        if isinstance(value, str) and value.lower() in ["nan", "not specified"]:
            return False

        # If value is a list, check each item
        if isinstance(value, list):
            for item in value:
                # Check if the item is a string and matches the specified values
                if isinstance(item, str) and item.lower() in ["nan", "not specified"]:
                    return False

        return True

    # Optimize 'city' and 'country'
    # If location_city is valid use it ('country'='JP" and location_country='Japan')
    for key in ["city", "country"]:
        location_model_key = f"location_model_{key}"
        # if not is_valid(data_dict.get(key)) and is_valid(
        #     data_dict.get(location_model_key)
        # ):
        if is_valid(data_dict.get(location_model_key)):
            data_dict[key] = data_dict[location_model_key]
        data_dict.pop(location_model_key, None)

    # Optimize 'ai' and 'involves_ai'
    if data_dict.get("ai") not in [0, 1] and is_valid(data_dict.get("involves_ai")):
        data_dict["ai"] = 1 if data_dict["involves_ai"] else 0
    data_dict.pop("involves_ai", None)
    if data_dict.get("ai") in [0, 1]:
        data_dict["ai"] = bool(data_dict["ai"])

    # Optimize 'salary_numerical'
    salary = data_dict.get("salary_numerical")
    print("salary", salary)
    if not is_valid(salary) or isinstance(salary, str):
        data_dict["salary_min"] = data_dict["salary_max"] = None
    elif (
        isinstance(salary, list)
        and len(salary) == 1
        and is_valid(salary[0])
        and salary[0] < 900000
        and salary[0] > 5
    ):
        data_dict["salary_min"] = data_dict["salary_max"] = salary[0]
    elif (
        isinstance(salary, list)
        and len(salary) == 2
        and all(is_valid(val) for val in salary)
        and all(val < 900000 for val in salary)
        and all(val > 5 for val in salary)
    ):
        data_dict["salary_min"], data_dict["salary_max"] = salary
    else:
        data_dict["salary_min"] = data_dict["salary_max"] = None

    print("salary_min", data_dict["salary_min"])
    print("salary_max", data_dict["salary_max"])
    print("salary_frequency", data_dict["salary_frequency"], "\n")
    data_dict.pop("salary_numerical", None)

    # Optimize 'job_skills'
    if is_valid(data_dict.get("required_skills")) and not is_valid(data_dict.get("skills")):
        data_dict["skills"] = data_dict["required_skills"]
    elif is_valid(data_dict.get("skills")):
        data_dict["skills"] = data_dict.get("skills").split(",")
    data_dict.pop("required_skills", None)

    # Optimize 'experience_years'
    if is_valid(data_dict.get("experience_years")):
        experience_years = data_dict["experience_years"]
        if isinstance(experience_years, str):
            data_dict["experience_years"] = None
        else:
            data_dict["experience_years"] = int(experience_years)

    # Replace 'Not specified' with None for all keys
    for key, value in data_dict.items():
        if not is_valid(value):
            data_dict[key] = None

    # Transform lists into strings
    for key, value in data_dict.items():
        if isinstance(value, list):
            data_dict[key] = ", ".join(value) if len(value) > 1 else value[0]

    # Transform values into lowercase strings
    lowercased_data = {
        key: value.lower() if isinstance(value, str) else value
        for key, value in data_dict.items()
    }

    return lowercased_data

# %%
list_of_dicts = []
for i, dict in enumerate(flattened_data):
    print("index", i)
    optimized_dict = optimize_keys(dict)
    list_of_dicts.append(optimized_dict)

# print(list_of_dicts[8978].keys())
print(list_of_dicts[8978])
# for i, dict in enumerate(list_of_dicts):
# print(list_of_dicts[2])
# print(dict.keys())
# if i == 5:
# break
# Out:
# index 0
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 1
# salary [17.25, 24.0]
# salary_min 17.25
# salary_max 24.0
# salary_frequency hourly
#
# index 2
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 3
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 4
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 5
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 6
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 7
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 8
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 10
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 11
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 12
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 13
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 14
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 15
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 16
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 17
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 18
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 19
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 20
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 21
# salary [250000.0, 600000.0]
# salary_min 250000.0
# salary_max 600000.0
# salary_frequency annually
#
# index 22
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 23
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 24
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 25
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 26
# salary [158000.0, 269000.0]
# salary_min 158000.0
# salary_max 269000.0
# salary_frequency annually
#
# index 27
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 28
# salary [225000.0, 250000.0]
# salary_min 225000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 29
# salary [110000.0, 120000.0]
# salary_min 110000.0
# salary_max 120000.0
# salary_frequency annually
#
# index 30
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 31
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 32
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 33
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 34
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 35
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 36
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 37
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 38
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 39
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 40
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 41
# salary [35000.0, 55000.0]
# salary_min 35000.0
# salary_max 55000.0
# salary_frequency monthly
#
# index 42
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 43
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 44
# salary [170000.0, 220000.0]
# salary_min 170000.0
# salary_max 220000.0
# salary_frequency annually
#
# index 45
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 46
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 47
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 48
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 49
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 50
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 51
# salary [70000.0, 80000.0]
# salary_min 70000.0
# salary_max 80000.0
# salary_frequency annually
#
# index 52
# salary [122000.0, 190000.0]
# salary_min 122000.0
# salary_max 190000.0
# salary_frequency annually
#
# index 53
# salary [179200.0, 215040.0]
# salary_min 179200.0
# salary_max 215040.0
# salary_frequency annually
#
# index 54
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 55
# salary [200000.0, 300000.0]
# salary_min 200000.0
# salary_max 300000.0
# salary_frequency annually
#
# index 56
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 57
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 58
# salary [170000.0, 220000.0]
# salary_min 170000.0
# salary_max 220000.0
# salary_frequency annually
#
# index 59
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 60
# salary [41.0, 53.0]
# salary_min 41.0
# salary_max 53.0
# salary_frequency hourly
#
# index 61
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 62
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 63
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 64
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 65
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 66
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 67
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 68
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 69
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 70
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 71
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 72
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 73
# salary [90000.0, 120000.0]
# salary_min 90000.0
# salary_max 120000.0
# salary_frequency annually
#
# index 74
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 75
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 76
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 77
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 78
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 79
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 80
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 81
# salary [100000.0, 200000.0]
# salary_min 100000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 82
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 83
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 84
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency monthly
#
# index 85
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 86
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 87
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 88
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 89
# salary [140000.0, 200000.0]
# salary_min 140000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 90
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 91
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 92
# salary [127000.0, 180000.0]
# salary_min 127000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 93
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 94
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 95
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 96
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 97
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 98
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 99
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 100
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 101
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 102
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 103
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 104
# salary [176000.0, 250000.0]
# salary_min 176000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 105
# salary [157000.0, 188400.0]
# salary_min 157000.0
# salary_max 188400.0
# salary_frequency annually
#
# index 106
# salary [240000.0, 280000.0]
# salary_min 240000.0
# salary_max 280000.0
# salary_frequency annually
#
# index 107
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 108
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 109
# salary [200000.0, 300000.0]
# salary_min 200000.0
# salary_max 300000.0
# salary_frequency annually
#
# index 110
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 111
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 112
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 113
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 114
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 115
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 116
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 117
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 118
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 119
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 120
# salary [500000.0, 1000000.0]
# salary_min None
# salary_max None
# salary_frequency annually
#
# index 121
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 122
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 123
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 124
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 125
# salary [50.0, 67.0]
# salary_min 50.0
# salary_max 67.0
# salary_frequency hourly
#
# index 126
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 127
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 128
# salary [165000.0, 200000.0]
# salary_min 165000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 129
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 130
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 131
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 132
# salary [4250.0, 6000.0]
# salary_min 4250.0
# salary_max 6000.0
# salary_frequency monthly
#
# index 133
# salary [160000.0, 200000.0]
# salary_min 160000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 134
# salary [6000.0, 9000.0]
# salary_min 6000.0
# salary_max 9000.0
# salary_frequency monthly
#
# index 135
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 136
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 137
# salary [14.03, 25.5]
# salary_min 14.03
# salary_max 25.5
# salary_frequency Not specified
#
# index 138
# salary [180000.0, 250000.0]
# salary_min 180000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 139
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 140
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 141
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 142
# salary [85000.0, 125000.0]
# salary_min 85000.0
# salary_max 125000.0
# salary_frequency annually
#
# index 143
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 144
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 145
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 146
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 147
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 148
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 149
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 150
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 151
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 152
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 153
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 154
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 155
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 156
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 157
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency monthly
#
# index 158
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 159
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 160
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 161
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 162
# salary [160000.0, 200000.0]
# salary_min 160000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 163
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 164
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 165
# salary [170112.0, 237000.0]
# salary_min 170112.0
# salary_max 237000.0
# salary_frequency annually
#
# index 166
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 167
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 168
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 169
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 170
# salary [158000.0, 269000.0]
# salary_min 158000.0
# salary_max 269000.0
# salary_frequency annually
#
# index 171
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 172
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 173
# salary []
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 174
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 175
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 176
# salary [175000.0, 275000.0]
# salary_min 175000.0
# salary_max 275000.0
# salary_frequency annually
#
# index 177
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 178
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 179
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 180
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 181
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 182
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 183
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 184
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 185
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 186
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 187
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 188
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 189
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 190
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 191
# salary [170112.0, 237000.0]
# salary_min 170112.0
# salary_max 237000.0
# salary_frequency annually
#
# index 192
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 193
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 194
# salary [189000.0, 237000.0]
# salary_min 189000.0
# salary_max 237000.0
# salary_frequency annually
#
# index 195
# salary [142000.0, 285000.0]
# salary_min 142000.0
# salary_max 285000.0
# salary_frequency annually
#
# index 196
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 197
# salary [170000.0, 210000.0]
# salary_min 170000.0
# salary_max 210000.0
# salary_frequency annually
#
# index 198
# salary [151200.0, 207907.0]
# salary_min 151200.0
# salary_max 207907.0
# salary_frequency annually
#
# index 199
# salary [158000.0, 269000.0]
# salary_min 158000.0
# salary_max 269000.0
# salary_frequency annually
#
# index 200
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 201
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 202
# salary [139863.0, 190545.0]
# salary_min 139863.0
# salary_max 190545.0
# salary_frequency Not specified
#
# index 203
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 204
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 205
# salary [170112.0, 237000.0]
# salary_min 170112.0
# salary_max 237000.0
# salary_frequency Not specified
#
# index 206
# salary [250000.0, 275000.0]
# salary_min 250000.0
# salary_max 275000.0
# salary_frequency annually
#
# index 207
# salary [122000.0, 190000.0]
# salary_min 122000.0
# salary_max 190000.0
# salary_frequency annually
#
# index 208
# salary [170112.0, 237000.0]
# salary_min 170112.0
# salary_max 237000.0
# salary_frequency Not specified
#
# index 209
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 210
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 211
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 212
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 213
# salary [237006.0, 302207.0]
# salary_min 237006.0
# salary_max 302207.0
# salary_frequency annually
#
# index 214
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 215
# salary [160000.0, 230000.0]
# salary_min 160000.0
# salary_max 230000.0
# salary_frequency annually
#
# index 216
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 217
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 218
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 219
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 220
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 221
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 222
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 223
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 224
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 225
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 226
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 227
# salary [12.86, 23.38]
# salary_min 12.86
# salary_max 23.38
# salary_frequency hourly
#
# index 228
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 229
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 230
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 231
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 232
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 233
# salary [237000.0, 284614.0]
# salary_min 237000.0
# salary_max 284614.0
# salary_frequency Not specified
#
# index 234
# salary [181400.0, 220000.0]
# salary_min 181400.0
# salary_max 220000.0
# salary_frequency annually
#
# index 235
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 236
# salary [190000.0, 240000.0]
# salary_min 190000.0
# salary_max 240000.0
# salary_frequency annually
#
# index 237
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 238
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 239
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 240
# salary [170112.0, 237000.0]
# salary_min 170112.0
# salary_max 237000.0
# salary_frequency annually
#
# index 241
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency hourly
#
# index 242
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 243
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 244
# salary [110000.0, 130000.0]
# salary_min 110000.0
# salary_max 130000.0
# salary_frequency annually
#
# index 245
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 246
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 247
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 248
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 249
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 250
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 251
# salary [150000.0, 225000.0]
# salary_min 150000.0
# salary_max 225000.0
# salary_frequency annually
#
# index 252
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 253
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 254
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 255
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 256
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 257
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 258
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 259
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 260
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 261
# salary [151000.0, 270000.0]
# salary_min 151000.0
# salary_max 270000.0
# salary_frequency annually
#
# index 262
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 263
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 264
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 265
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 266
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 267
# salary [550.0, 760.0]
# salary_min 550.0
# salary_max 760.0
# salary_frequency hourly
#
# index 268
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 269
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 270
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 271
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 272
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 273
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 274
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 275
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 276
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 277
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 278
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 279
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 280
# salary [170000.0, 215000.0]
# salary_min 170000.0
# salary_max 215000.0
# salary_frequency annually
#
# index 281
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 282
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 283
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 284
# salary [108000.0, 148500.0]
# salary_min 108000.0
# salary_max 148500.0
# salary_frequency annually
#
# index 285
# salary [185000.0, 220000.0]
# salary_min 185000.0
# salary_max 220000.0
# salary_frequency annually
#
# index 286
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 287
# salary [120000.0, 150000.0]
# salary_min 120000.0
# salary_max 150000.0
# salary_frequency annually
#
# index 288
# salary [155000.0, 180000.0]
# salary_min 155000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 289
# salary [165000.0, 210000.0]
# salary_min 165000.0
# salary_max 210000.0
# salary_frequency annually
#
# index 290
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 291
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 292
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 293
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 294
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 295
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 296
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 297
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 298
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 299
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 300
# salary [129000.0, 190000.0]
# salary_min 129000.0
# salary_max 190000.0
# salary_frequency annually
#
# index 301
# salary [105000.0, 154000.0]
# salary_min 105000.0
# salary_max 154000.0
# salary_frequency annually
#
# index 302
# salary [191000.0, 280000.0]
# salary_min 191000.0
# salary_max 280000.0
# salary_frequency annually
#
# index 303
# salary [216000.0, 317000.0]
# salary_min 216000.0
# salary_max 317000.0
# salary_frequency annually
#
# index 304
# salary [133000.0, 196000.0]
# salary_min 133000.0
# salary_max 196000.0
# salary_frequency annually
#
# index 305
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 306
# salary [95000.0, 135000.0]
# salary_min 95000.0
# salary_max 135000.0
# salary_frequency Not specified
#
# index 307
# salary [137000.0, 200000.0]
# salary_min 137000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 308
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 309
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 310
# salary [160000.0, 280000.0]
# salary_min 160000.0
# salary_max 280000.0
# salary_frequency annually
#
# index 311
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 312
# salary [160000.0, 210000.0]
# salary_min 160000.0
# salary_max 210000.0
# salary_frequency annually
#
# index 313
# salary [220000.0, 280000.0]
# salary_min 220000.0
# salary_max 280000.0
# salary_frequency annually
#
# index 314
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 315
# salary [245000.0, 450000.0]
# salary_min 245000.0
# salary_max 450000.0
# salary_frequency annually
#
# index 316
# salary [245000.0, 450000.0]
# salary_min 245000.0
# salary_max 450000.0
# salary_frequency annually
#
# index 317
# salary [295000.0, 440000.0]
# salary_min 295000.0
# salary_max 440000.0
# salary_frequency annually
#
# index 318
# salary [160000.0, 385000.0]
# salary_min 160000.0
# salary_max 385000.0
# salary_frequency annually
#
# index 319
# salary [200000.0, 370000.0]
# salary_min 200000.0
# salary_max 370000.0
# salary_frequency annually
#
# index 320
# salary [160000.0, 385000.0]
# salary_min 160000.0
# salary_max 385000.0
# salary_frequency annually
#
# index 321
# salary [200000.0, 385000.0]
# salary_min 200000.0
# salary_max 385000.0
# salary_frequency annually
#
# index 322
# salary [245000.0, 385000.0]
# salary_min 245000.0
# salary_max 385000.0
# salary_frequency annually
#
# index 323
# salary [310000.0, 385000.0]
# salary_min 310000.0
# salary_max 385000.0
# salary_frequency annually
#
# index 324
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 325
# salary [200000.0, 370000.0]
# salary_min 200000.0
# salary_max 370000.0
# salary_frequency annually
#
# index 326
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 327
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 328
# salary [25.0, 50.0]
# salary_min 25.0
# salary_max 50.0
# salary_frequency hourly
#
# index 329
# salary [155000.0, 185000.0]
# salary_min 155000.0
# salary_max 185000.0
# salary_frequency annually
#
# index 330
# salary [155000.0, 185000.0]
# salary_min 155000.0
# salary_max 185000.0
# salary_frequency annually
#
# index 331
# salary [25.0, 50.0]
# salary_min 25.0
# salary_max 50.0
# salary_frequency hourly
#
# index 332
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 333
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 334
# salary [12.86, 23.38]
# salary_min 12.86
# salary_max 23.38
# salary_frequency Not specified
#
# index 335
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 336
# salary [17.5, 32.5]
# salary_min 17.5
# salary_max 32.5
# salary_frequency Not specified
#
# index 337
# salary [20.63, 37.5]
# salary_min 20.63
# salary_max 37.5
# salary_frequency hourly
#
# index 338
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 339
# salary [162170.0, 252990.0]
# salary_min 162170.0
# salary_max 252990.0
# salary_frequency annually
#
# index 340
# salary [86520.0, 123600.0]
# salary_min 86520.0
# salary_max 123600.0
# salary_frequency annually
#
# index 341
# salary [162170.0, 252990.0]
# salary_min 162170.0
# salary_max 252990.0
# salary_frequency annually
#
# index 342
# salary [162170.0, 252990.0]
# salary_min 162170.0
# salary_max 252990.0
# salary_frequency annually
#
# index 343
# salary [86520.0, 123600.0]
# salary_min 86520.0
# salary_max 123600.0
# salary_frequency annually
#
# index 344
# salary [162170.0, 252990.0]
# salary_min 162170.0
# salary_max 252990.0
# salary_frequency annually
#
# index 345
# salary [162170.0, 252990.0]
# salary_min 162170.0
# salary_max 252990.0
# salary_frequency annually
#
# index 346
# salary [199000.0, 300000.0]
# salary_min 199000.0
# salary_max 300000.0
# salary_frequency Not specified
#
# index 347
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 348
# salary [220000.0, 260000.0]
# salary_min 220000.0
# salary_max 260000.0
# salary_frequency annually
#
# index 349
# salary [180000.0, 220000.0]
# salary_min 180000.0
# salary_max 220000.0
# salary_frequency annually
#
# index 350
# salary [300000.0, 370000.0]
# salary_min 300000.0
# salary_max 370000.0
# salary_frequency annually
#
# index 351
# salary [200000.0, 250000.0]
# salary_min 200000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 352
# salary [280000.0, 370000.0]
# salary_min 280000.0
# salary_max 370000.0
# salary_frequency annually
#
# index 353
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 354
# salary [220000.0, 260000.0]
# salary_min 220000.0
# salary_max 260000.0
# salary_frequency annually
#
# index 355
# salary [250000.0, 450000.0]
# salary_min 250000.0
# salary_max 450000.0
# salary_frequency annually
#
# index 356
# salary [300000.0, 450000.0]
# salary_min 300000.0
# salary_max 450000.0
# salary_frequency annually
#
# index 357
# salary [280000.0, 520000.0]
# salary_min 280000.0
# salary_max 520000.0
# salary_frequency annually
#
# index 358
# salary [280000.0, 520000.0]
# salary_min 280000.0
# salary_max 520000.0
# salary_frequency annually
#
# index 359
# salary [300000.0, 450000.0]
# salary_min 300000.0
# salary_max 450000.0
# salary_frequency annually
#
# index 360
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 361
# salary [85000.0, 110000.0]
# salary_min 85000.0
# salary_max 110000.0
# salary_frequency annually
#
# index 362
# salary [130000.0, 160000.0]
# salary_min 130000.0
# salary_max 160000.0
# salary_frequency annually
#
# index 363
# salary [70000.0, 120000.0]
# salary_min 70000.0
# salary_max 120000.0
# salary_frequency annually
#
# index 364
# salary [200000.0, 300000.0]
# salary_min 200000.0
# salary_max 300000.0
# salary_frequency annually
#
# index 365
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 366
# salary [120000.0, 180000.0]
# salary_min 120000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 367
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 368
# salary [120000.0, 180000.0]
# salary_min 120000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 369
# salary [120000.0, 180000.0]
# salary_min 120000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 370
# salary [100000.0, 180000.0]
# salary_min 100000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 371
# salary [120000.0, 180000.0]
# salary_min 120000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 372
# salary [100000.0, 180000.0]
# salary_min 100000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 373
# salary [180000.0, 250000.0]
# salary_min 180000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 374
# salary [100000.0, 180000.0]
# salary_min 100000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 375
# salary [100000.0, 180000.0]
# salary_min 100000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 376
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 377
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 378
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 379
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 380
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 381
# salary [160000.0, 250000.0]
# salary_min 160000.0
# salary_max 250000.0
# salary_frequency annually
#
# index 382
# salary [120000.0, 180000.0]
# salary_min 120000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 383
# salary [200000.0, 300000.0]
# salary_min 200000.0
# salary_max 300000.0
# salary_frequency annually
#
# index 384
# salary [120000.0, 180000.0]
# salary_min 120000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 385
# salary [120000.0, 180000.0]
# salary_min 120000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 386
# salary [200000.0, 300000.0]
# salary_min 200000.0
# salary_max 300000.0
# salary_frequency annually
#
# index 387
# salary [200000.0, 300000.0]
# salary_min 200000.0
# salary_max 300000.0
# salary_frequency annually
#
# index 388
# salary [120000.0, 180000.0]
# salary_min 120000.0
# salary_max 180000.0
# salary_frequency annually
#
# index 389
# salary [150000.0, 160000.0]
# salary_min 150000.0
# salary_max 160000.0
# salary_frequency annually
#
# index 390
# salary [195000.0, 200000.0]
# salary_min 195000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 391
# salary [100000.0, 500000.0]
# salary_min 100000.0
# salary_max 500000.0
# salary_frequency annually
#
# index 392
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 393
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 394
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 395
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 396
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 397
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 398
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 399
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 400
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 401
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 402
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 403
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 404
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 405
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 406
# salary [165000.0, 220000.0]
# salary_min 165000.0
# salary_max 220000.0
# salary_frequency annually
#
# index 407
# salary [195000.0, 240000.0]
# salary_min 195000.0
# salary_max 240000.0
# salary_frequency annually
#
# index 408
# salary [140000.0, 165000.0]
# salary_min 140000.0
# salary_max 165000.0
# salary_frequency annually
#
# index 409
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 410
# salary [175000.0, 210000.0]
# salary_min 175000.0
# salary_max 210000.0
# salary_frequency annually
#
# index 411
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 412
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 413
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 414
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 415
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 416
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 417
# salary [38.0, 48.0]
# salary_min 38.0
# salary_max 48.0
# salary_frequency hourly
#
# index 418
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 419
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 420
# salary [100000.0, 185000.0]
# salary_min 100000.0
# salary_max 185000.0
# salary_frequency annually
#
# index 421
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 422
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 423
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 424
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 425
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 426
# salary [125000.0, 195000.0]
# salary_min 125000.0
# salary_max 195000.0
# salary_frequency annually
#
# index 427
# salary [19.23, 24.04]
# salary_min 19.23
# salary_max 24.04
# salary_frequency hourly
#
# index 428
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 429
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 430
# salary [81080.0, 141650.0]
# salary_min 81080.0
# salary_max 141650.0
# salary_frequency Not specified
#
# index 431
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 432
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 433
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 434
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 435
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 436
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 437
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 438
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 439
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 440
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 441
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 442
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 443
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 444
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 445
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 446
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 447
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 448
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 449
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 450
# salary [112070.0, 189546.0]
# salary_min 112070.0
# salary_max 189546.0
# salary_frequency annually
#
# index 451
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 452
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 453
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 454
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 455
# salary [1000000.0, 850000.0]
# salary_min None
# salary_max None
# salary_frequency annually
#
# index 456
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 457
# salary [1000000.0, 850000.0]
# salary_min None
# salary_max None
# salary_frequency annually
#
# index 458
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 459
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 460
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 461
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 462
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 463
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 464
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 465
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 466
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 467
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 468
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 469
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 470
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 471
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 472
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 473
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 474
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 475
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 476
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 477
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 478
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 479
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 480
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 481
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 482
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 483
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 484
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 485
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 486
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 487
# salary Not specified
# salary_min None
# salary_max None
# ...
# salary [112000.0, 218400.0]
# salary_min 112000.0
# salary_max 218400.0
# salary_frequency annually
#
# index 8987
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 8988
# salary [140000.0, 200000.0]
# salary_min 140000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 8989
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 8990
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 8991
# salary [117300.0, 195500.0]
# salary_min 117300.0
# salary_max 195500.0
# salary_frequency annually
#
# index 8992
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 8993
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 8994
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 8995
# salary [230000.0, 262500.0]
# salary_min 230000.0
# salary_max 262500.0
# salary_frequency annually
#
# index 8996
# salary [1800.0, 3000.0]
# salary_min 1800.0
# salary_max 3000.0
# salary_frequency hourly
#
# index 8997
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 8998
# salary [1500.0, 2398.0]
# salary_min 1500.0
# salary_max 2398.0
# salary_frequency hourly
#
# index 8999
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9000
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9001
# salary [138900.0, 256500.0]
# salary_min 138900.0
# salary_max 256500.0
# salary_frequency annually
#
# index 9002
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9003
# salary [112000.0, 218400.0]
# salary_min 112000.0
# salary_max 218400.0
# salary_frequency annually
#
# index 9004
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9005
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9006
# salary [120869.0, 191027.0]
# salary_min 120869.0
# salary_max 191027.0
# salary_frequency annually
#
# index 9007
# salary [119500.0, 149500.0, 179500.0]
# salary_min None
# salary_max None
# salary_frequency annually
#
# index 9008
# salary [154700.0, 224250.0]
# salary_min 154700.0
# salary_max 224250.0
# salary_frequency annually
#
# index 9009
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9010
# salary [67000.0, 106000.0]
# salary_min 67000.0
# salary_max 106000.0
# salary_frequency annually
#
# index 9011
# salary [135150.0, 195500.0]
# salary_min 135150.0
# salary_max 195500.0
# salary_frequency annually
#
# index 9012
# salary [22517500.0, 35958500.0]
# salary_min None
# salary_max None
# salary_frequency annually
#
# index 9013
# salary [147100.0, 286000.0]
# salary_min 147100.0
# salary_max 286000.0
# salary_frequency annually
#
# index 9014
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9015
# salary [10400000.0, 20200000.0]
# salary_min None
# salary_max None
# salary_frequency annually
#
# index 9016
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9017
# salary [110000.0, 220000.0]
# salary_min 110000.0
# salary_max 220000.0
# salary_frequency annually
#
# index 9018
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9019
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency annually
#
# index 9020
# salary [110500.0, 176000.0]
# salary_min 110500.0
# salary_max 176000.0
# salary_frequency annually
#
# index 9021
# salary [138230.0, 264200.0]
# salary_min 138230.0
# salary_max 264200.0
# salary_frequency annually
#
# index 9022
# salary [147100.0, 286000.0]
# salary_min 147100.0
# salary_max 286000.0
# salary_frequency annually
#
# index 9023
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9024
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9025
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9026
# salary [13890000.0, 25650000.0]
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9027
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9028
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9029
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9030
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9031
# salary [96200.0, 158900.0]
# salary_min 96200.0
# salary_max 158900.0
# salary_frequency annually
#
# index 9032
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9033
# salary [172000.0, 293000.0]
# salary_min 172000.0
# salary_max 293000.0
# salary_frequency annually
#
# index 9034
# salary [79735.0, 149026.0]
# salary_min 79735.0
# salary_max 149026.0
# salary_frequency annually
#
# index 9035
# salary [5146.0, 5718.0]
# salary_min 5146.0
# salary_max 5718.0
# salary_frequency hourly
#
# index 9036
# salary [151500.0, 294700.0]
# salary_min 151500.0
# salary_max 294700.0
# salary_frequency annually
#
# index 9037
# salary [10233600.0, 17399200.0]
# salary_min None
# salary_max None
# salary_frequency annually
#
# index 9038
# salary [1400.0]
# salary_min 1400.0
# salary_max 1400.0
# salary_frequency monthly
#
# index 9039
# salary [115000.0, 223600.0]
# salary_min 115000.0
# salary_max 223600.0
# salary_frequency annually
#
# index 9040
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9041
# salary [132000.0, 198000.0]
# salary_min 132000.0
# salary_max 198000.0
# salary_frequency annually
#
# index 9042
# salary [115000.0, 223600.0]
# salary_min 115000.0
# salary_max 223600.0
# salary_frequency annually
#
# index 9043
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9044
# salary [115000.0, 223600.0]
# salary_min 115000.0
# salary_max 223600.0
# salary_frequency annually
#
# index 9045
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9046
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9047
# salary [134500.0, 261500.0]
# salary_min 134500.0
# salary_max 261500.0
# salary_frequency annually
#
# index 9048
# salary [130000.0, 170000.0]
# salary_min 130000.0
# salary_max 170000.0
# salary_frequency annually
#
# index 9049
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9050
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9051
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9052
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9053
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9054
# salary [115000.0, 223600.0]
# salary_min 115000.0
# salary_max 223600.0
# salary_frequency annually
#
# index 9055
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9056
# salary [136000.0, 200000.0]
# salary_min 136000.0
# salary_max 200000.0
# salary_frequency annually
#
# index 9057
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9058
# salary [100000.0, 110000.0]
# salary_min 100000.0
# salary_max 110000.0
# salary_frequency annually
#
# index 9059
# salary [105700.0, 205600.0]
# salary_min 105700.0
# salary_max 205600.0
# salary_frequency annually
#
# index 9060
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9061
# salary [170000.0, 230000.0]
# salary_min 170000.0
# salary_max 230000.0
# salary_frequency annually
#
# index 9062
# salary [152000.0, 158000.0]
# salary_min 152000.0
# salary_max 158000.0
# salary_frequency annually
#
# index 9063
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9064
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9065
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9066
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9067
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9068
# salary [115000.0, 223600.0]
# salary_min 115000.0
# salary_max 223600.0
# salary_frequency annually
#
# index 9069
# salary [80000.0, 120000.0]
# salary_min 80000.0
# salary_max 120000.0
# salary_frequency annually
#
# index 9070
# salary [104000.0, 143000.0]
# salary_min 104000.0
# salary_max 143000.0
# salary_frequency annually
#
# index 9071
# salary [151500.0, 294700.0]
# salary_min 151500.0
# salary_max 294700.0
# salary_frequency annually
#
# index 9072
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9073
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9074
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9075
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9076
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9077
# salary [110000.0, 140000.0]
# salary_min 110000.0
# salary_max 140000.0
# salary_frequency annually
#
# index 9078
# salary [151000.0, 188500.0]
# salary_min 151000.0
# salary_max 188500.0
# salary_frequency annually
#
# index 9079
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9080
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9081
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9082
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9083
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9084
# salary [148750.0, 175000.0]
# salary_min 148750.0
# salary_max 175000.0
# salary_frequency annually
#
# index 9085
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9086
# salary [98000.0, 210000.0]
# salary_min 98000.0
# salary_max 210000.0
# salary_frequency annually
#
# index 9087
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9088
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9089
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9090
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9091
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9092
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9093
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9094
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9095
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9096
# salary [184000.0, 230000.0]
# salary_min 184000.0
# salary_max 230000.0
# salary_frequency annually
#
# index 9097
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9098
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9099
# salary [120000.0, 150000.0]
# salary_min 120000.0
# salary_max 150000.0
# salary_frequency annually
#
# index 9100
# salary [147753.0, 221630.0]
# salary_min 147753.0
# salary_max 221630.0
# salary_frequency annually
#
# index 9101
# salary Not specified
# salary_min None
# salary_max None
# salary_frequency Not specified
#
# index 9102
# salary [80000.0, 325000.0]
# salary_min 80000.0
# salary_max 325000.0
# salary_frequency annually
#
# index 9103
# salary [97935.0, 171816.0]
# salary_min 97935.0
# salary_max 171816.0
# salary_frequency annually
#
# index 9104
# salary [80000.0, 110000.0]
# salary_min 80000.0
# salary_max 110000.0
# salary_frequency annually
#
# {'job_id': 68430, 'created_at': '2024-02-04', 'title': 'product manager, public sector', 'skills': 'computer science, api, product management, product development, customer success, product design, ai, llms, manager, operations, quantitative, machine learning, hubs, computer vision, generative ai, openai, data', 'company_id': 8281, 'apply_url': 'https://boards.greenhouse.io/scaleai/jobs/4355003005?utm_source=found.dev', 'city': 'washington dc', 'country': 'united states', 'slug': 'scale-ai-product-manager-public-sector-spfg', 'ai': True, 'approved': 1, 'company_name': 'scale ai', 'cleaned_description': "job application for product manager public sector at scale ai\\[apply now\\](#app)\\# product manager public sectorat scale ai\\[(view all jobs)\\](/scaleai)st louis mo; washington dcai has the potential to exponentially augment human intelligence every person will have a personal tutor coach assistant personal shopper travel guide and therapist leading ai companies are hustling to build large language models (llms) while public sector and large enterprises figure out how to integrate them into their productsscale is looking for an experienced federal product manager to drive the development of innovative new products within our federal space you will work cross-functionally with engineering design sales marketing customer success and operations to take products from pain point to fully-deployed solution and coordinate with company leadership on roadmap strategy and priorities you will be responsible for driving roadmap definition and execution; using both qualitative customer & scaler feedback and quantitative metrics & kpi's to guide decisions and measure successthe ideal candidate is someone who can lead the development of federal-specific products by understanding customer challenges and integrating solutions from our commercial product suite they will collaborate closely with engineering and design leads and align the teams outcomes with the companys forward trajectory they will leverage deep knowledge of the federal sector to identify market gaps and craft a comprehensive product strategy to address them ideal candidates will bring a strategic perspective to our team ensuring that our solutions not only meet current customer needs but also anticipate future demands within the federal space they should be adept at cross-functional collaboration clearly communicating product vision and driving a culture of excellence and proactive engagement\\*\\*you will:\\*\\*\\- lead the end-to-end product development of multiple products from ideation to development to launch to deployment\\- deeply understand the customer by wearing their shoes conducting user interviews setting up analytics\\- define product pricing and be responsible for product p&l\\- tactically you will write product requirement documents gather stakeholder feedback drive execution program manage (ie tickets) lead dogfooding sessions keep documentation up to date deploy products and drive adoption across intended users and present at product reviews\\- drive collaboration across engineering product design go-to-market operations marketing finance\\- ensure communication to customer stakeholders is top-notch\\- effectively prioritize resources to balance speed and quality\\- partner with department heads to create compelling product roadmaps and visions\\*\\*ideally youd have:\\*\\*\\- \\*\\*clearance eligible required; existing ts/sci preferred\\*\\*\\- strong software engineering background (a degree in computer science or equivalent)\\- 2+ years of experience in product management\\- track record of product development in the federal environment\\- deep familiarity with the federal space and ideally prior military or usg service\\- experience building products with some ai/ml components\\- excellent communication and presentation skills\\- ability to solve difficult problems in high-stakes environments\\- excitement to do intense and high impact work\\- ability t ...

# %%
import pandas as pd
import tiktoken
import logging
logger = logging.getLogger(__name__)

# The data in a dataframe
df1 = pd.DataFrame(list_of_dicts)
df1 = df1.rename(columns={"ai": "involves_ai"})
df1 = df1.rename(columns={"title": "job_title"})
df1 = df1.rename(columns={"skills": "job_skills"})

df1['created_at'] = pd.to_datetime(df1['created_at'])
df1 = df1.rename(columns={"created_at": "creation_date"})

df1 = df1.rename(columns={"cleaned_description": "job_listing_text"})
df1 = df1.drop(
    ["slug", "approved", "chain_of_thought", "job_type_reasoning", "remote_reasoning"],
    axis=1,
)

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    try:
        encoding = tiktoken.get_encoding(encoding_name)
        num_tokens = len(encoding.encode(string))
        return num_tokens
    except Exception as e:
        logger.error(f"Error calculating number of tokens: {e}")
        return 0

df1["num_tokens"] = df1["job_listing_text"].apply(
        lambda x: num_tokens_from_string(x, "cl100k_base")
    )

# # Finding and printing the max value in the salary_max column
# max_salary_max = df1['salary_max'].max()
# print(f"Maximum value in 'salary_max' column: {max_salary_max}")

# # Finding and printing the min value in the salary_min column
# min_salary_min = df1['salary_min'].min()
# print(f"Minimum value in 'salary_min' column: {min_salary_min}")

# # Print the row with the max salary_max value
# print("Row with the maximum 'salary_max' value:")
# print(df1[df1['salary_max'] == max_salary_max])

# # Print the row with the min salary_min value
# print("\nRow with the minimum 'salary_min' value:")
# print(df1[df1['salary_min'] == min_salary_min])

# print(df1.head(1))
# print(df1.dtypes)
# print("\n")
print(df1.info())
# print(df1.shape)
# print(df1.columns)
# print(len(df1))

# df1.to_pickle("../data/extracted_cleaned_df_feb5.pkl")
# print(df1.to_markdown())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9105 entries, 0 to 9104
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_id                9105 non-null   int64
#  1   creation_date         9105 non-null   datetime64[ns]
#  2   job_title             9105 non-null   object
#  3   job_skills            9105 non-null   object
#  4   company_id            9105 non-null   int64
#  5   apply_url             9105 non-null   object
#  6   city                  7913 non-null   object
#  7   country               8814 non-null   object
#  8   involves_ai           9105 non-null   bool
#  9   company_name          9105 non-null   object
#  10  job_listing_text      9105 non-null   object
#  11  jobs_towardsai_url    9105 non-null   object
#  12  company_info          9105 non-null   object
#  13  role_description      9105 non-null   object
#  14  preferred_skills      6395 non-null   object
#  15  salary_reasoning      8008 non-null   object
#  16  salary_frequency      2688 non-null   object
#  17  salary_currency       2924 non-null   object
#  18  job_type_answer       8073 non-null   object
#  19  min_experience_years  5995 non-null   object
#  20  regions_or_states     5497 non-null   object
#  21  continent             8178 non-null   object
#  22  experience_level      5519 non-null   object
#  23  remote_answer         4494 non-null   object
#  24  salary_min            2669 non-null   float64
#  25  salary_max            2669 non-null   float64
#  26  num_tokens            9105 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(3), object(20)
# memory usage: 1.8+ MB
# None

# %% [markdown]
# ## Embed and upload dataset to Deep Lake

# %%
# import pandas as pd
# import time
# import os
# from buster.documents_manager import DeepLakeDocumentsManager
# from dotenv import load_dotenv
# import numpy as np
# import json
# import deeplake
# import tiktoken

# load_dotenv(".env")
# ACTIVELOOP_TOKEN = os.getenv("ACTIVELOOP_TOKEN")


# # df1 = pd.read_csv("../data/jobs_original_data_2.csv", low_memory=False, on_bad_lines='warn')
# df1 = pd.read_json("../data/formatted_jobs.json")
# df1['created_at'] = df1['created_at'].astype(str) # convert to string, else its not json serializable
# print(len(df1))
# # print(df1.dtypes)
# # print("\n")
# # print(df1.info())
# # print(df1.shape)
# # print(df1.columns)

# df1 = df1.dropna(subset="cleaned_description")
# # df1.to_csv("../data/jobs_cleaned_data2.csv", index=False)


# df1 = df1.rename(columns={'cleaned_description': 'content'})


# def num_tokens_from_string(string: str, encoding_name: str) -> int:
#     """Returns the number of tokens in a text string."""
#     encoding = tiktoken.get_encoding(encoding_name)
#     num_tokens = len(encoding.encode(string))
#     return num_tokens

# df1['num_tokens'] = df1['content'].apply(lambda x: num_tokens_from_string(x, "cl100k_base"))

# # Now, you can filter the DataFrame to only keep rows with num_tokens less than 8000
# df1_filtered = df1[df1['num_tokens'] < 8000]
# print("number of rows:", len(df1_filtered))
# df1_filtered.drop('num_tokens', axis=1, inplace=True)

# # df2 = df1.head(5000)


# # # # dataset_path = "hub://towards_ai/ai-jobs-dataset"
# dataset_path = "local_dataset"

# dm = DeepLakeDocumentsManager(
#     vector_store_path=dataset_path,
#     overwrite=True, # does not work when the dataset is empty?
#     # required_columns=["url", "content", "source", "title"],
# )

# # # Check if embeddings are present, computes them if not
# # if "embedding" not in df.columns:
# #     # df["embedding"] = compute_embeddings_parallelized(df, embedding_fn=embedding_fn, num_workers=num_workers)
# #     df.loc[:, "embedding"] = compute_embeddings_parallelized(df, embedding_fn=embedding_fn, num_workers=num_workers)

# dm.batch_add(
#     df=df1_filtered,
#     batch_size=10000, # very important to this be greater than the whole dataset
#     min_time_interval=60,
#     num_workers=32,
#     csv_overwrite=False,
# )

# %%
# import os
# import deeplake
# # Renaming source 'langchain to 'langchain_docs'
# # db = deeplake.VectorStore("local_dataset", overwrite=False, read_only=False)
# # db = deeplake.VectorStore("hub://towards_ai/ai-jobs", overwrite=False, read_only=True)
# # db.summary()
# # metadata_list = db.dataset["metadata"].data(aslist=True)['value']
# # print(len(db.dataset["metadata"]))
# # print(len(metadata_list))
# deeplake.deepcopy("local_dataset", "hub://towards_ai/ai-jobs-data-9105-3072", overwrite=True, read_only=False)
# # db

# %%
# import os
# import openai
# from dotenv import load_dotenv
# import nested_structure as bm

# load_dotenv(".env")
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# from IPython.display import Markdown, display
# from llama_index import SQLDatabase

# %%
# from sqlalchemy import (
#     create_engine,
#     MetaData,
#     Table,
#     Column,
#     String,
#     Integer,
#     Float,
#     Boolean,
#     Text,
# )
# from sqlalchemy import insert
# import json

# %%
# # Define the engine and metadata
# engine = create_engine("sqlite:///:memory:")
# metadata_obj = MetaData()

# # Modify the table definition to include salary_min and salary_max
# job_listing_details_table = Table(
#     "job_listing_details",
#     metadata_obj,
#     Column("jobs_towardsai_url", String, primary_key=True),

# )

# # Recreate the table with the new structure
# metadata_obj.create_all(engine)

# %%
# # create city SQL table
# table_name = "city_stats"
# city_stats_table = Table(
#     table_name,
#     metadata_obj,
#     Column("city_name", String(16), primary_key=True),
#     Column("population", Integer),
#     Column("country", String(16), nullable=False),
# )
# metadata_obj.create_all(engine)

# %%
# from llama_index import SQLDatabase, ServiceContext
# from llama_index.llms import OpenAI

# llm = OpenAI(temperature=0.1, model="gpt-3.5-turbo")
# service_context = ServiceContext.from_defaults(llm=llm)
# # sql_database = SQLDatabase(engine, include_tables=["city_stats"])
# sql_database = SQLDatabase(engine, include_tables=["job_listing_details"])

# %%
# sql_database = SQLDatabase(engine, include_tables=["city_stats"])
# from sqlalchemy import insert

# rows = [
#     {"city_name": "Toronto", "population": 2930000, "country": "Canada"},
#     {"city_name": "Tokyo", "population": 13960000, "country": "Japan"},
#     {
#         "city_name": "Chicago",
#         "population": 2679000,
#         "country": "United States",
#     },
#     {"city_name": "Seoul", "population": 9776000, "country": "South Korea"},
# ]
# for row in rows:
#     stmt = insert(job_listing_details_table).values(**row)
#     with engine.begin() as connection:
#         cursor = connection.execute(stmt)

# %%
# # view current table
# stmt = select(
#     city_stats_table.c.city_name,
#     city_stats_table.c.population,
#     city_stats_table.c.country,
# ).select_from(city_stats_table)

# with engine.connect() as connection:
#     results = connection.execute(stmt).fetchall()
#     print(results)

# %%
# from sqlalchemy import text

# with engine.connect() as con:
#     rows = con.execute(text("SELECT * FROM job_listing_details ORDER BY CAST(salary_numerical AS REAL) DESC;"))
#     i = 0
#     for row in rows:
#         print(row)
#         i += 1
#         if i > 10:
#             break

# %%
# from llama_index.indices.struct_store.sql_query import NLSQLTableQueryEngine

# query_engine = NLSQLTableQueryEngine(
#     sql_database=sql_database,
#     tables=["job_listing_details"],
#     verbose=True,
# )
# query_str = "Which job has the highest salary?"
# response = query_engine.query(query_str)
# display(Markdown(f"<b>{response}</b>"))

# %%
# display(Markdown(f"<b>{response}</b>"))

# %%
# from sqlalchemy.sql import select

# # Function to fetch and display 5 elements from the database
# def fetch_five_records(engine, table):
#     # Create a SELECT query that selects all columns from the table
#     query = select(table).limit(5)

#     # Execute the query
#     with engine.connect() as connection:
#         result = connection.execute(query)

#         # Fetch the results
#         records = result.fetchall()

#         # Display the records
#         for record in records:
#             print(record)

# # Call the function to fetch and display records
# fetch_five_records(engine, job_listing_details_table)
